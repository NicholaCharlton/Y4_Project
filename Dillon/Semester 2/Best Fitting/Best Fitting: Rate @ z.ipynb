# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from pylab import cm
from hoki.constants import BPASS_NUM_METALLICITIES

# %%
plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 22})
plt.rcParams['axes.linewidth'] = 2

# %%
empmodel = h5py.File(f"/Users/dillon/Desktop/empmodel_170_100_split.h5", "r")
harikane22 = h5py.File(f"/Users/dillon/Desktop/harikane22_135_100_split.h5", "r")
MD = h5py.File(f"/Users/dillon/Desktop/MD_170_100_split.h5", "r")
Millimillennium = h5py.File(f"/Users/dillon/Desktop/millimillennium_170_100_split.h5", "r")
EAGLE = h5py.File(f"/Users/dillon/Desktop/EAGLE_100_100_split.h5", "r")
TNG = h5py.File(f"/Users/dillon/Desktop/TNG_135_300_split.h5", "r")

# %% [markdown]
# Solid line is z = 0, dashed line is z ~ 11

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 16))
fig.subplots_adjust(hspace=0.05, wspace=0.05)

axs = axs.flatten()


for ax in axs:
    ax.grid()
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(1e-5, 4e-2)
    ax.set_ylim(1e-2, 7.2e4)
    ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in')
    ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in')
    ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', pad=7)
    #ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in')
    ax.xaxis.set_major_locator(mpl.ticker.LogLocator(base=10, numticks=16))
    ax.yaxis.set_major_locator(mpl.ticker.LogLocator(base=10, numticks=16))

for ax in axs[0:1]:
    ax.plot(BPASS_NUM_METALLICITIES, TNG['Ia_rates'][:, 0], marker="x", color = '#1f77b4', lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(TNG['CCSN_rates'], axis=1)[:, 0], color = '#ff7f0e', marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, TNG['LGRB_rates'][:, 0], marker="x", lw=2, color = '#2ca02c', label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, TNG['PISN_rates'][:, 0], marker="x", lw=2, color = '#d62728', label='PISN')
    ax.text(0.05, 0.89, "TNG", transform=ax.transAxes,fontsize=20)
    
    ax.plot(BPASS_NUM_METALLICITIES, TNG['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(TNG['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, TNG['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, TNG['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)


    ax.xaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())
    
for ax in axs[1:2]:
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['Ia_rates'][:, 0], marker="x", lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(EAGLE['CCSN_rates'], axis=1)[:, 0], marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['LGRB_rates'][:, 0], marker="x", lw=2, label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['PISN_rates'][:, 0], marker="x", lw=2, label='PISN')
    ax.text(0.45, 0.89, "EAGLE", transform=ax.transAxes,fontsize=20)
    
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(EAGLE['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, EAGLE['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)
    
    legend = ax.legend(frameon=False, fontsize=12, loc='upper left', bbox_to_anchor=(0, 1))
    for line in legend.get_lines():
        line.set_linewidth(2)
        
        
    ax.yaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

for ax in axs[2:3]:
    ax.plot(BPASS_NUM_METALLICITIES, MD['Ia_rates'][:, 0], marker="x", lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(MD['CCSN_rates'], axis=1)[:, 0], marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, MD['LGRB_rates'][:, 0], marker="x", lw=2, label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, MD['PISN_rates'][:, 0], marker="x", lw=2, label='PISN')
    ax.text(0.05, 0.89, "Madau & Dicksinson", transform=ax.transAxes,fontsize=20)
    
    ax.plot(BPASS_NUM_METALLICITIES, MD['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(MD['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, MD['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, MD['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)
    
    ax.xaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())


for ax in axs[3:4]:
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['Ia_rates'][:, 0], marker="x", lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(Millimillennium['CCSN_rates'], axis=1)[:, 0], marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['LGRB_rates'][:, 0], marker="x", lw=2, label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['PISN_rates'][:, 0], marker="x", lw=2, label='PISN')
    ax.text(0.05, 0.89, "Millimillennium", transform=ax.transAxes,fontsize=20)
    
    
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(Millimillennium['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, Millimillennium['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)
    
    
    ax.yaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())
    
    
    
for ax in axs[4:5]:
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['Ia_rates'][:, 0], marker="x", lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(empmodel['CCSN_rates'], axis=1)[:, 0], marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['LGRB_rates'][:, 0], marker="x", lw=2, label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['PISN_rates'][:, 0], marker="x", lw=2, label='PISN')
    ax.text(0.05, 0.89, "Empirical Model", transform=ax.transAxes,fontsize=20)
    
    
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(empmodel['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, empmodel['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)
    
for ax in axs[5:6]:
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['Ia_rates'][:, 0], marker="x", lw=2, label='Ia')
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(harikane22['CCSN_rates'], axis=1)[:, 0], marker="x", lw=2, label='CCSN')
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['LGRB_rates'][:, 0], marker="x", lw=2, label='LGRB')
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['PISN_rates'][:, 0], marker="x", lw=2, label='PISN')
    ax.text(0.05, 0.89, "Harikane 22", transform=ax.transAxes,fontsize=20)
    
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['Ia_rates'][:, 98], '--', marker="x", color = '#1f77b4', lw = 2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, np.sum(harikane22['CCSN_rates'], axis=1)[:, 98], '--', color = '#ff7f0e', marker="x", lw=2, alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['LGRB_rates'][:, 98], '--', marker="x", lw=2, color = '#2ca02c', alpha = 0.7)
    ax.plot(BPASS_NUM_METALLICITIES, harikane22['PISN_rates'][:, 98], '--', marker="x", lw=2, color = '#d62728', alpha = 0.7)
    
    ax.yaxis.set_major_formatter(mpl.ticker.NullFormatter())
    ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())

    
fig.text(0.523, -0.01, r'Metallicity', ha='center', va='center')
    
plt.tight_layout()

plt.show()

# %% [markdown]
# ### DTD for Each Metallicity

# %% [markdown]
# This code takes the data associated with the Briel paper and plots the DTD for each event type for the 13 different BPASS metallicities

# %% [markdown]
# ##### Imports

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import scipy.integrate as spi
from pylab import cm

# %% [markdown]
# ##### Data

# %%
path = "/Users/dillon/Desktop"
data = h5py.File(f"{path}/data.h5", "r")

DTD = data["DTD"]
bin_centres = data['DTD'].attrs['bin_centres']

BPASS_METALS = ["10$^{-5}$","10$^{-4}$","0.001", "0.002", "0.003", "0.004", "0.006", "0.008", "0.010", "0.014", "0.020", "0.030", "0.040" ]

# %%
event_types = ["Ia", "IIP", "II", "Ib", "Ic", "LGRB", "PISNe", "BBH", "BHNS", "BNS"]
metallicities = ["z001", "z002", "z003", "z004", "z006", "z008", "z010", "z014", "z020", "z030", "z040", "zem4", "zem5" ]


event_total = {}
for i in (metallicities):
    event_total[i] = {}
    for j in event_types:
        event_total[i][j] = DTD[j][i][:]
    event_total[i]["CCSN"] = event_total[i]["II"] + event_total[i]["Ib"] + event_total[i]["Ic"] + event_total[i]["IIP"]

# %% [markdown]
# ##### Plotting

# %% [markdown]
# ##### ia

# %%
event_type_to_plot = "Ia"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/Ia DTD.png")

# %% [markdown]
# ##### CCSN

# %%
event_type_to_plot = "CCSN"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/CCSN DTD.png")

# %% [markdown]
# ##### LGRB

# %%
event_type_to_plot = "LGRB"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/LGRB DTD.png")

# %% [markdown]
# ##### PISN

# %%
event_type_to_plot = "PISNe"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/PISN DTD.png")

# %% [markdown]
# ##### BBH

# %%
event_type_to_plot = "BBH"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/BBH DTD.png")

# %% [markdown]
# ##### BNS

# %%
event_type_to_plot = "BNS"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/BNS DTD.png")

# %% [markdown]
# ##### BHNS

# %%
event_type_to_plot = "BHNS"


plt.figure(figsize=(10, 6))


for i, metallicity in enumerate(metallicities):
    DTD_values = event_total[metallicity][event_type_to_plot]
    color = plt.cm.coolwarm(i / (len(metallicities) - 1))  
    plt.step(bin_centres, DTD_values, label=f"{metallicity}", color=color)

plt.yscale('log')
    
plt.xlabel("Delay Time [$log_{10} (yr)$]")
plt.ylabel("Event Rate [$yr^{-1} M_{\odot}^{-1}$]")


NUM_COLORS = len(metallicities)
cm = plt.get_cmap('coolwarm')
cmap = plt.get_cmap("coolwarm", NUM_COLORS)
norm = mpl.colors.BoundaryNorm(np.arange(NUM_COLORS + 1), NUM_COLORS)
norm.spacing = 'uniform'  
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])


cbar = plt.colorbar(sm)
cbar.set_ticks(np.arange(NUM_COLORS) + 0.5)
cbar.set_ticklabels(BPASS_METALS)
cbar.set_label("Metallicity")

plt.savefig("/Users/dillon/Desktop/DTD(z)/BHNS DTD.png")
